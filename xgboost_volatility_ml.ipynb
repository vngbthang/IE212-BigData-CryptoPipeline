# %% [markdown]
# # XGBoost Volatility Pipeline
#
# Notebook này gọi pipeline trong `xgboost_volatility_pipeline.py` để train, evaluate và export artifacts cho `BTC/USDT` và `ETH/USDT`.
#
# Nếu môi trường chưa có dependency ML, cài bằng `requirements-ml.txt` trước khi chạy notebook.

# %%
# Uncomment nếu bạn đang chạy trong notebook kernel mới.
# %pip install -r requirements-ml.txt

# %%
from xgboost_volatility_pipeline import DEFAULT_DATASET_PATH, DEFAULT_ARTIFACTS_DIR, run_pipeline

print(f"Resolved dataset path: {DEFAULT_DATASET_PATH.resolve()}")
print(f"Artifacts directory: {DEFAULT_ARTIFACTS_DIR.resolve()}")

# %%
metrics_summary, metrics_summary_df = run_pipeline()
metrics_summary_df
